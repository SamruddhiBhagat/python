# %%
input("Enter name = ")
# Out:
# Enter name =  samruddhi
# 'samruddhi'

# %%
# addition of two numbers
num1 = input("Enter first number = ")
num2 = input("Enter second number = ")
# Out:
# Enter first number =  10
# Enter second number =  20

# %%
addition = num1 + num2
print(addition)
# Out:
# 1020

# %%
# above is concatenation happed because python takes the input in string format 
# the python devlover stores the input in string format beacause the string can store integer,float and any other data types
# but for example integer can not store the string 

# and here is string that's why addition is not possible, beacuse string can perform concatenation  
# if we want to perform addition of num1 and num2 before that we need to perform type conversion

# %%
# there are two types of type conversion
#  1. Implicit - as a python programmer we dont need to tell python to perform type conversion 
#  2. Explicit - likwise in explicit we need python to perform type conversion

# %%
# examples of implicit type conversion 
5 + 4.5
# Out:
# 9.5

# %%
6 + 4 +9j
# Out:
# (10+9j)

# %%
4.5 + 4 + 5j
# Out:
# (8.5+5j)

# %%
# there are different built in functions in python for explicit type conversion

#int

int(4.5)
# Out:
# 4

# %%
float(4)
# Out:
# 4.0

# %%
bool(1)
# Out:
# True

# %%
complex(2)
# Out:
# (2+0j)

# %%
list("hello")
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
print(num1)
print(num2)
print(addition)
# from the above
# Out:
# 10
# 20
# 1020

# %%
add = int(num1) + int(num2)
print(add)
# Out:
# 30
