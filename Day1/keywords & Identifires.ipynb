# %%
# python is a case sensitive language 
# and it has total 33 keywords

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# identifire - usedto identify name of variable, class, object, function, etc
# only starts with alphabet or _ under-score
# keyword can not be identifire
# can not start

# %%
name = "Riya"
print(name)
# Out:
# Riya

# %%
name1 = "sakshi"
print(name1)
# Out:
# sakshi

# %%
_ = "student"
print(_)
# Out:
# student

# %%
_name = "raj"
print(_name)
# Out:
# raj
