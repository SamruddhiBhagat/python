# %%
#integer
print(10)
# Out:
# 10

# %%
#float
print(10.3)
# Out:
# 10.3

# %%
#string
print('hello')
print("hello")
print("""hello""")
# Out:
# hello
# hello
# hello

# %%
#complex
print(5+4j)
# Out:
# (5+4j)

# %%
#list
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#dictionary
print({"Name":"Riya","Age":20,"Gender":"Female"})
# Out:
# {'Name': 'Riya', 'Age': 20, 'Gender': 'Female'}

# %%
print({"Name":"Riya","Age":20,"Gender":"Female"},
      {"Name":"Ram","Age":24,"Gender":"Male"})
# Out:
# {'Name': 'Riya', 'Age': 20, 'Gender': 'Female'} {'Name': 'Ram', 'Age': 24, 'Gender': 'Male'}
