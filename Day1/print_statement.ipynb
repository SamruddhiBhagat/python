# %%
print("hello")
# Out:
# hello

# %%
print("India","Japan","Nepal")
# Out:
# India Japan Nepal

# %%
print("India","Japan","Nepal",sep = '/')
# Out:
# India/Japan/Nepal

# %%
print("hello")
print ("world")
# Out:
# hello
# world

# %%
print("hello",end = ' ')
print ("world")
# Out:
# hello world

# %%
print(10,20)
# Out:
# 10 20

# %%
print(10.5,20.7)
# Out:
# 10.5 20.7

# %%
print(10.5,"Samruddhi",3)
# Out:
# 10.5 Samruddhi 3

# %%
print(10.5,"Samruddhi",3, sep = '/')
# Out:
# 10.5/Samruddhi/3

# %%
print("hello",end = '/')
print ("world")
# Out:
# hello/world
