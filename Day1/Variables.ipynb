# %%
# Python is dynyamic typing language
# dynamic typing - we dont need to declare data-type first before the veriable 


#dynamic typing - we need to declare data-type first before the variable

# %%
name = "Riya"
print(name)
# Out:
# Riya

# %%
#Python uses dynamic binding
#dynamic binding - means the same variable can store different type of values for exmaple first store integer next time in same variable
#float or boolean values


#static binding is complete opposite of dynamic binding

# %%
print(name)
# Out:
# Riya

# %%
name =10
print(name)
# Out:
# 10

# %%
name = True
print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 name = true
#       2 print(name)
#
# NameError: name 'true' is not defined
